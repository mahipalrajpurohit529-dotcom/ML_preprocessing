# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# Assignment 1 :-

# %%
df = pd.read_csv(r"C:\Users\asus\Downloads\titanic - titanic.csv")

# %%
df.shape
# Out:
# (418, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# df.isna().sum()

# %% [markdown]
# assignment 2:-

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns=['Survived'])
y =df['Survived']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# assignment 3 :-

# %%
ct = ColumnTransformer(transformers=[
    ('tnf1',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),['Name','Sex','Ticket','Cabin','Embarked']),
],remainder='passthrough')

# %%
x_train_transformed = ct.fit_transform(x_train)
x_test_transformed = ct.fit_transform(x_test)

# %% [markdown]
# assignment 4 :-

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
ct2 = ColumnTransformer(transformers=[
    ('tnf1',StandardScaler(),['Fare','Age'])
],remainder='passthrough')

# %% [markdown]
# assignment 6:-

# %%
from sklearn.preprocessing import FunctionTransformer
