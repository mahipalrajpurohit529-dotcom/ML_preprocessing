# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer 
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv(r"C:\Users\asus\Downloads\cars - cars.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
x = df.drop(columns=['km_driven'])
y = df['km_driven']

# %%
cat = x.select_dtypes(include='object').columns
num = x.select_dtypes(exclude='object').columns

# %%
transformers = ColumnTransformer(transformers=[
    ('standerisingn',StandardScaler(),num),
    ('encoding',OneHotEncoder(),cat)
],remainder='passthrough')

# %%
Pipe = Pipeline(steps=[
    ('transfer',transformers),
    ('regression',LinearRegression())
])

# %%
x_train ,x_test ,y_train ,y_test = train_test_split(x,y,test_size=0.2,random_state=34)

# %%
Pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('transfer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('standerisingn',
#                                                   StandardScaler(),
#                                                   Index(['year', 'selling_price'], dtype='object')),
#                                                  ('encoding', OneHotEncoder(),
#                                                   Index(['name', 'fuel', 'seller_type', 'transmission', 'owner'], dtype='object'))])),
#                 ('regression', LinearRegression())])

# %%
predictions = Pipe.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 predictions = Pipe.predict(x_test)
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\pipeline.py:745, in Pipeline.predict(self, X, **params)
#     743 if not _routing_enabled():
#     744     for _, name, transform in self._iter(with_final=False):
# --> 745         Xt = transform.transform(Xt)
#     746     return self.steps[-1][1].predict(Xt, **params)
#     748 # metadata routing enabled
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\compose\_column_transformer.py:1099, in ColumnTransformer.transform(self, X, **params)
#    1096 else:
#    1097     routed_params = self._get_empty_routing()
# -> 1099 Xs = self._call_func_on_transformers(
#    1100     X,
#    1101     None,
#    1102     _transform_one,
#    1103     column_as_labels=fit_dataframe_and_transform_dataframe,
#    1104     routed_params=routed_params,
#    1105 )
#    1106 self._validate_output(Xs)
#    1108 if not Xs:
#    1109     # All transformers are None
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\compose\_column_transformer.py:901, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     889             extra_args = {}
#     890         jobs.append(
#     891             delayed(func)(
#     892                 transformer=clone(trans) if not fitted else trans,
#    (...)    898             )
#     899         )
# --> 901     return Parallel(n_jobs=self.n_jobs)(jobs)
#     903 except ValueError as e:
#     904     if "Expected 2D array, got 1D array instead" in str(e):
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\pipeline.py:1464, in _transform_one(transformer, X, y, weight, params)
#    1442 def _transform_one(transformer, X, y, weight, params):
#    1443     """Call transform and apply weight to output.
#    1444
#    1445     Parameters
#    (...)   1462         This should be of the form ``process_routing()["step_name"]``.
#    1463     """
# -> 1464     res = transformer.transform(X, **params.transform)
#    1465     # if we have a weight for this transformer, multiply output
#    1466     if weight is None:
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_encoders.py:1051, in OneHotEncoder.transform(self, X)
#    1046     warn_on_unknown = self.drop is not None and self.handle_unknown in {
#    1047         "ignore",
#    1048         "infrequent_if_exist",
#    1049     }
#    1050     handle_unknown = self.handle_unknown
# -> 1051 X_int, X_mask = self._transform(
#    1052     X,
#    1053     handle_unknown=handle_unknown,
#    1054     ensure_all_finite="allow-nan",
#    1055     warn_on_unknown=warn_on_unknown,
#    1056 )
#    1058 n_samples, n_features = X_int.shape
#    1060 if self._drop_idx_after_grouping is not None:
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_encoders.py:220, in _BaseEncoder._transform(self, X, handle_unknown, ensure_all_finite, warn_on_unknown, ignore_category_indices)
#     215 if handle_unknown == "error":
#     216     msg = (
#     217         "Found unknown categories {0} in column {1}"
#     218         " during transform".format(diff, i)
#     219     )
# --> 220     raise ValueError(msg)
#     221 else:
#     222     if warn_on_unknown:
#
# ValueError: Found unknown categories ['Mahindra Renault Logan 1.5 DLX Diesel', 'Tata Aria Pure LX 4x2', 'Tata New Safari DICOR 2.2 VX 4x4', 'Maruti 800 DUO AC LPG', 'Hyundai Grand i10 CRDi Asta', 'Maruti Ciaz ZXi Plus', 'Maruti Swift ZXi BSIV', 'Maruti Swift AMT VXI', 'Nissan Kicks XL D BSIV', 'Hyundai Verna 1.6 i ABS', 'Hyundai Santro Xing GL Plus LPG', 'Chevrolet Aveo 1.4 CNG', 'Maruti S-Presso VXI Plus', 'Land Rover Discovery S 2.0 SD4', 'Volvo V40 D3 R Design', 'Mahindra Scorpio VLX AT 2WD BSIII', 'Fiat Punto EVO 1.3 Dynamic', 'Honda Civic 1.8 (E) MT', 'Hyundai i20 1.4 CRDi Era', 'Mahindra Verito Vibe 1.5 dCi D6', 'Ford Figo 1.5 Sports Edition MT', 'Fiat Linea 1.3 Multijet Emotion', 'Maruti 800 Std BSIII', 'Tata Indigo CS LE (TDI) BS-III', 'Maruti Celerio VXI Optional', 'Ford Figo Aspire 1.5 Ti-VCT Titanium', 'Maruti Swift ZDI Plus', 'Mahindra Ingenio CRDe', 'Toyota Innova 2.5 EV Diesel PS 7 Seater BSIII', 'Kia Seltos HTK Plus AT D', 'Hyundai Accent GLE', 'Land Rover Discovery Sport TD4 HSE 7S', 'Hyundai Verna 1.4 CRDi', 'Hyundai i20 Magna 1.4 CRDi', 'Skoda Yeti Ambition 4X2', 'Volkswagen Ameo 1.5 TDI Highline 16 Alloy', 'Maruti Alto K10 LXI CNG Optional', 'Maruti Alto K10 LXI CNG', 'Audi A5 Sportback', 'Hyundai Verna 1.6 Xi ABS', 'Hyundai i20 1.4 Magna ABS', 'Maruti Ertiga BSIV ZXI', 'Mahindra Scorpio VLX 2WD ABS AT BSIII', 'Honda Jazz 1.2 V i VTEC', 'Chevrolet Aveo 1.4 LT BSIV', 'Volkswagen Vento 1.5 TDI Comfortline AT', 'Maruti Swift VXI BSIV', 'Tata Sumo Victa EX 7/9 Str BSII', 'Maruti Omni 8 Seater BSII', 'Fiat Avventura MULTIJET Emotion', 'Chevrolet Spark 1.0 LT Option Pack w/ Airbag', 'Toyota Innova 2.5 E Diesel MS 7-seater', 'Mahindra Supro VX 8 Str', 'Renault Captur 1.5 Diesel RXT Mono', 'Volkswagen Vento 1.0 TSI Highline Plus', 'Skoda Laura Elegance 2.0 TDI CR AT', 'Datsun GO Plus Remix Limited Edition', 'Skoda Rapid 1.5 TDI AT Ambition', 'Mahindra XUV500 AT W6 2WD', 'Nissan Terrano XL Plus ICC WT20 SE', 'Tata Zest Quadrajet 1.3 XM', 'BMW X1 sDrive20d M Sport', 'Toyota Innova 2.5 EV Diesel MS 7 Str BSIII', 'Mercedes-Benz New C-Class 200 CDI Classic', 'Volkswagen Vento IPL II Diesel Trendline', 'Ford Ikon 1.8 D', 'Tata Indica DLX', 'Hyundai i20 Asta (o) 1.4 CRDi (Diesel)', 'Honda Accord 2.4 AT', 'Mahindra Xylo H4 ABS', 'Tata Nano Std', 'Chevrolet Tavera Neo LS B3 - 7(C) seats BSIII', 'Honda City i-DTEC ZX', 'Hyundai i20 2015-2017 Sportz Option 1.4 CRDi', 'Ford Fiesta 1.6 Duratec EXI Ltd', 'Skoda Yeti Ambition 4WD', 'Renault Triber RXT BSIV', 'Honda Brio 1.2 S Option MT', 'Ford Ecosport Thunder Edition Diesel', 'Hyundai Verna Transform VTVT', 'Ford Fiesta Classic 1.6 Duratec CLXI', 'Ford EcoSport 1.5 Ti VCT MT Trend BSIV', 'Ford Endeavour 4x2 XLT', 'Mahindra Thar 4X2', 'Ford Freestyle Titanium Plus Diesel', 'Chevrolet Aveo U-VA 1.2', 'Ford Figo 1.5P Titanium AT', 'Tata Indica Vista Aqua 1.3 Quadrajet ABS BSIV', 'Chevrolet Beat Diesel LT Option', 'BMW 7 Series Signature 730Ld', 'Honda City Edge Edition Diesel SV', 'Mahindra XUV500 W7', 'Maruti Zen D', 'Tata Indigo GLE BSIII', 'Toyota Innova 2.0 GX 8 STR BSIV', 'Mahindra Bolero SLX 4WD BSIII', 'Hyundai Santro LE', 'Maruti Omni 5 Str STD', 'Skoda Rapid 1.5 TDI Ambition BSIV', 'Hyundai Getz 1.3 GVS', 'Volkswagen Jetta 1.9 L TDI', 'Mahindra Bolero 2011-2019 SLX 2WD BSIII', 'Chevrolet Enjoy TCDi LS 8 Seater', 'Hyundai Elantra CRDi SX', 'Mahindra Scorpio SLE BS IV', 'Mahindra KUV 100 D75 K4 Plus 5Str', 'Hyundai i20 1.2 Magna Executive', 'Toyota Etios VXD', 'Isuzu D-Max V-Cross Standard', 'Maruti Omni Maruti Omni MPI STD BSIII 5-STR W/ IMMOBILISER', 'Mahindra XUV500 W6 1.99 mHawk', 'Mahindra Thar CRDe AC', 'Maruti Swift Dzire AMT ZXI', 'Hyundai Santro Xing GLS CNG', 'Maruti Swift DDiS VDI', 'Tata Indigo LS BSII', 'Fiat 500 Lounge', 'Tata Nexon 1.5 Revotorq XM', 'Tata Sumo GX TC 8 Str', 'Ford Endeavour XLT TDCi 4X2', 'Honda Civic 1.8 MT Sport', 'Maruti Ertiga SHVS LDI', 'Chevrolet Enjoy TCDi LTZ 7 Seater', 'Hyundai i20 Magna Optional 1.2', 'Tata Indica V2 2001-2011 DLS BSII ...
