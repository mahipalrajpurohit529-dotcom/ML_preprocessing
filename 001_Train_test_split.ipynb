# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# How Machine Learning Works ?277?
# Data Gathering --- > Data Dividation --- > Data Cleaning and Preprocessing ---- >
# Select a ML model --- > Model training --- > Model Prediction --- > Model Perfornace Evaluation.

# Data(df) --- > x(Independent data) + y(Dependent or target data)
# x ---- > x_train , x_test
# y --- > y_train , y_test

# %%
df = pd.read_csv(r"C:\Users\asus\Downloads\covid_toy - covid_toy.csv")

# %%
df.isna().sum()     # as we dont want null values in our data
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['fever' ] = df['fever' ].fillna(df['fever'].mean())

# %%
df.isna().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
x = df.drop(columns=['has_covid'])      # independent data
x.shape
# Out:
# (100, 5)

# %%
y = df['has_covid']     # dependent data
y.shape
# Out:
# (100,)

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.3.5)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Using cached scipy-1.17.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.3)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.8.0-cp313-cp313-win_amd64.whl (8.0 MB)
# Using cached scipy-1.17.0-cp313-cp313-win_amd64.whl (36.3 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
#
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    ---------------------------------------- 3/3 [scikit-learn]
#
# Successfully installed scikit-learn-1.8.0 scipy-1.17.0 threadpoolctl-3.6.0

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train , y_test = train_test_split(x,
y,
test_size=0.2,
random_state=42)

# %%
print("Total shape of df:", df.shape)
print("------------------------------------")
print("Input data shape:", x.shape)
print("x_train data shape:", x_train.shape)
print("x_test data shape:", x_test.shape)
print("---------------------------------")
print("Target data shape:", y.shape)
print("y_train data shape:", y_train.shape)
print("y_test data shape:", y_test.shape)
# Out:
# Total shape of df: (100, 6)
# ------------------------------------
# Input data shape: (100, 5)
# x_train data shape: (80, 5)
# x_test data shape: (20, 5)
# ---------------------------------
# Target data shape: (100,)
# y_train data shape: (80,)
# y_test data shape: (20,)
