# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\asus\Downloads\covid_toy - covid_toy.csv")

# %%
df.isna().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['fever'] = df['fever'].fillna(df['fever'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    object
#  2   fever      100 non-null    float64
#  3   cough      100 non-null    object
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['cough'] = lb.fit_transform(df['cough'])
df['city'] = lb.fit_transform(df['city'])
df['has_covid'] = lb.fit_transform(df['has_covid'])
df['gender'] = lb.fit_transform(df['gender'])

# %%
x = df.drop(columns=['has_covid'])
y = df['has_covid']

# %%
from sklearn.preprocessing import FunctionTransformer

# %%
log_transform = FunctionTransformer(np.sqrt)
y_transformed = log_transform.transform(y)
print(y_transformed)
# Out:
# 0     0.0
# 1     1.0
# 2     0.0
# 3     0.0
# 4     0.0
#      ...
# 95    0.0
# 96    1.0
# 97    0.0
# 98    0.0
# 99    1.0
# Name: has_covid, Length: 100, dtype: float64

# %%
log_transform = FunctionTransformer(np.sqrt)
x_transformed = log_transform.transform(x)
print(x_transformed)
# Out:
#          age  gender      fever  cough      city
# 0   7.745967     1.0  10.148892    0.0  1.414214
# 1   5.196152     1.0  10.000000    0.0  1.000000
# 2   6.480741     1.0  10.049876    0.0  1.000000
# 3   5.567764     0.0   9.899495    0.0  1.414214
# 4   8.062258     0.0  10.049876    0.0  1.732051
# ..       ...     ...        ...    ...       ...
# 95  3.464102     0.0  10.198039    0.0  0.000000
# 96  7.141428     0.0  10.049876    1.0  1.414214
# 97  4.472136     0.0  10.049876    0.0  0.000000
# 98  2.236068     0.0   9.899495    1.0  1.732051
# 99  3.162278     0.0   9.899495    1.0  1.414214
#
# [100 rows x 5 columns]
