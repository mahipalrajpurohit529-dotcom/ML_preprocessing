# %%
# APYORI MODEL (Apriori Algorithm)
# The Apyori model is a Python implementation of the Apriori Algorithm, which is used in Association Rule Learning. It helps in finding relationships between items in a dataset.
# It is widely used in market basket analysis (e.g., which products are bought together).
# It works on the idea that:
# “If an itemset is frequent, then all of its subsets must also be frequent.”

# Working of Apriori:
# Generate all possible item combinations.
# Calculate their support.
# Remove itemsets with support less than minimum threshold.
# Generate association rules using confidence and lift.




# SUPPORT
# Support measures how frequently an itemset appears in the dataset.

# Support(A)=
# Total number of transactions
# Number of transactions containing A

# Value range: 0 to 1
# Higher support → item appears more often.

# 👉 Example:
# If 20 out of 100 transactions contain bread → support = 0.2





# CONFIDENCE
# Confidence measures how likely item B is purchased when item A is purchased.

# Confidence(A→B)=
# Support(A)
# Support(A∩B)

# Value range: 0 to 1
# Higher confidence → stronger rule.

# 👉 Example:
# If 10 transactions contain both A and B, and 20 contain A → confidence = 10/20 = 0.5





# LIFT
# Lift measures how much more likely item B is purchased with A compared to buying B alone.

# Lift(A→B)=
# Support(B)
# Confidence(A→B)

# Interpretation:
# Lift = 1 → No association (independent)
# Lift > 1 → Positive association (good rule)
# Lift < 1 → Negative association

# 👉 Example:
# If confidence = 0.5 and support(B) = 0.25 → lift = 2 (strong relation)

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\asus\Downloads\market_basket - market_basket.csv",header=None)

# %%
df.shape
# Out:
# (7501, 20)

# %%
# Data Processing
transactions = []
for i in range(0,7501):
    transactions.append([str(df.values[i,j]) for j in range(0,20)])

#Training the dataset
from apyori import apriori
rules = apriori(transactions ,
    min_support = 0.003,
    min_confidence = 0.2,
    min_lift = 3,
    min_length = 2)

#Visualizing the results
a = list(rules)
result = [list(a[i][0]) for i in range(0 , len(a))]

#(3items * 7 days in week)/(Total Rows in dataset 7501)

# %%
# Data Processing
transactions = []
for i in range(0,7501):
  transactions.append([str(df.values[i,j]) for j in range(0,20)])

#Training the dataset
from apyori import apriori
rules = apriori(transactions ,
            min_support = 0.003,   #(3items * 7 days in week)/(Total Rows in dataset 7501)
            min_confidence = 0.2,
            min_lift = 3 ,
            min_length = 2)

#Visualizing the results
a = list(rules)
result = [list(a[i][0]) for i in range(0, len(a))]

# %%
result
# Out:
# [['chicken', 'light cream'],
#  ['escalope', 'mushroom cream sauce'],
#  ['escalope', 'pasta'],
#  ['fromage blanc', 'honey'],
#  ['ground beef', 'herb & pepper'],
#  ['tomato sauce', 'ground beef'],
#  ['olive oil', 'light cream'],
#  ['whole wheat pasta', 'olive oil'],
#  ['shrimp', 'pasta'],
#  ['spaghetti', 'milk', 'avocado'],
#  ['burgers', 'milk', 'cake'],
#  ['burgers', 'turkey', 'chocolate'],
#  ['burgers', 'turkey', 'milk'],
#  ['tomatoes', 'frozen vegetables', 'cake'],
#  ['spaghetti', 'ground beef', 'cereals'],
#  ['ground beef', 'chicken', 'milk'],
#  ['nan', 'chicken', 'light cream'],
#  ['chicken', 'olive oil', 'milk'],
#  ['spaghetti', 'chicken', 'olive oil'],
#  ['shrimp', 'chocolate', 'frozen vegetables'],
#  ['ground beef', 'chocolate', 'herb & pepper'],
#  ['chocolate', 'soup', 'milk'],
#  ['spaghetti', 'cooking oil', 'ground beef'],
#  ['herb & pepper', 'ground beef', 'eggs'],
#  ['spaghetti', 'red wine', 'eggs'],
#  ['escalope', 'nan', 'mushroom cream sauce'],
#  ['escalope', 'pasta', 'nan'],
#  ['ground beef', 'herb & pepper', 'french fries'],
#  ['fromage blanc', 'honey', 'nan'],
#  ['green tea', 'tomatoes', 'frozen vegetables'],
#  ['spaghetti', 'ground beef', 'frozen vegetables'],
#  ['olive oil', 'milk', 'frozen vegetables'],
#  ['soup', 'milk', 'frozen vegetables'],
#  ['tomatoes', 'milk', 'frozen vegetables'],
#  ['shrimp', 'mineral water', 'frozen vegetables'],
#  ['spaghetti', 'olive oil', 'frozen vegetables'],
#  ['spaghetti', 'shrimp', 'frozen vegetables'],
#  ['shrimp', 'tomatoes', 'frozen vegetables'],
#  ['spaghetti', 'tomatoes', 'frozen vegetables'],
#  ['spaghetti', 'grated cheese', 'ground beef'],
#  ['green tea', 'ground beef', 'tomatoes'],
#  ['ground beef', 'herb & pepper', 'milk'],
#  ['mineral water', 'ground beef', 'herb & pepper'],
#  ['nan', 'ground beef', 'herb & pepper'],
#  ['spaghetti', 'ground beef', 'herb & pepper'],
#  ['ground beef', 'olive oil', 'milk'],
#  ['ground beef', 'soup', 'milk'],
#  ['nan', 'tomato sauce', 'ground beef'],
#  ['spaghetti', 'ground beef', 'pepper'],
#  ['spaghetti', 'shrimp', 'ground beef'],
#  ['spaghetti', 'tomato sauce', 'ground beef'],
#  ['spaghetti', 'mineral water', 'light cream'],
#  ['nan', 'olive oil', 'light cream'],
#  ['shrimp', 'olive oil', 'milk'],
#  ['soup', 'olive oil', 'milk'],
#  ['spaghetti', 'olive oil', 'milk'],
#  ['tomatoes', 'soup', 'milk'],
#  ['spaghetti', 'whole wheat pasta', 'milk'],
#  ['soup', 'mineral water', 'olive oil'],
#  ['whole wheat pasta', 'mineral water', 'olive oil'],
#  ['nan', 'whole wheat pasta', 'olive oil'],
#  ['nan', 'shrimp', 'pasta'],
#  ['pancakes', 'spaghetti', 'olive oil'],
#  ['spaghetti', 'tomatoes', 'olive oil'],
#  ['spaghetti', 'whole wheat rice', 'tomatoes'],
#  ['spaghetti', 'nan', 'milk', 'avocado'],
#  ['burgers', 'nan', 'milk', 'cake'],
#  ['burgers', 'nan', 'turkey', 'chocolate'],
#  ['burgers', 'turkey', 'nan', 'milk'],
#  ['nan', 'tomatoes', 'frozen vegetables', 'cake'],
#  ['spaghetti', 'nan', 'ground beef', 'cereals'],
#  ['nan', 'ground beef', 'chicken', 'milk'],
#  ['nan', 'chicken', 'olive oil', 'milk'],
#  ['spaghetti', 'nan', 'chicken', 'olive oil'],
#  ['mineral water', 'ground beef', 'chocolate', 'eggs'],
#  ['mineral water', 'ground beef', 'chocolate', 'frozen vegetables'],
#  ['spaghetti', 'ground beef', 'chocolate', 'frozen vegetables'],
#  ['mineral water', 'chocolate', 'milk', 'frozen vegetables'],
#  ['spaghetti', 'chocolate', 'milk', 'frozen vegetables'],
#  ['shrimp', 'mineral water', 'chocolate', 'frozen vegetables'],
#  ['nan', 'shrimp', 'chocolate', 'frozen vegetables'],
#  ['nan', 'ground beef', 'chocolate', 'herb & pepper'],
#  ['nan', 'chocolate', 'soup', 'milk'],
#  ['spaghetti', 'mineral water', 'chocolate', 'olive oil'],
#  ['spaghetti', 'shrimp', 'mineral water', 'chocolate'],
#  ['spaghetti', 'nan', 'cooking oil', 'ground beef'],
#  ['mineral water', 'eggs', 'milk', 'frozen vegetables'],
#  ['nan', 'herb & pepper', 'ground beef', 'eggs'],
#  ['spaghetti', 'nan', 'red wine', 'eggs'],
#  ['nan', 'ground beef', 'herb & pepper', 'french fries'],
#  ['spaghetti', 'mineral water', 'frozen smoothie', 'milk'],
#  ['green tea', 'nan', 'tomatoes', 'frozen vegetables'],
#  ['mineral water', 'ground beef', 'milk', 'frozen vegetables'],
#  ['spaghetti', 'ground beef', 'milk', 'frozen vegetables'],
#  ['mineral water', 'ground beef', 'spaghetti', 'frozen vegetables'],
#  ['spaghetti', 'nan', 'ground beef', 'frozen vegetables'],
#  ['mineral water', 'olive oil', 'milk', 'frozen vegetables'],
#  ['mineral water', 'soup', 'milk', 'frozen vegetables'],
#  ['spaghetti', 'mineral water', 'milk', 'frozen vegetables'],
#  ['nan', 'olive oil', 'milk', 'frozen vegetables'],
#  ['nan', 'soup', 'milk', 'frozen vegetables'],
#  ['nan', 'tomatoes', 'milk', 'frozen vegetables'],
#  ['nan', 'shrimp', 'mineral water', 'frozen vegetables'],
#  ['spaghetti', 'shrimp', 'mineral water', 'frozen vegetables'],
#  ['spaghetti', 'mineral water', 'tomatoes', 'frozen vegetables'],
#  ['spaghetti', 'nan', 'olive oil', 'frozen vegetables'],
#  ['spaghetti', 'nan', 'shrimp', 'frozen vegetables'],
#  ['nan', 'shrimp', 'tomatoes', 'frozen vegetables'],
#  ['spaghetti', 'nan', 'tomatoes', 'frozen vegetables'],
#  ['spaghetti', 'nan', 'grated cheese', 'ground beef'],
#  ['green tea', 'nan', 'ground beef', 'tomatoes'],
#  ['nan', 'ground beef', 'herb & pepper', 'milk'],
#  ['mineral water', 'nan', 'ground beef', 'herb & pepper'],
#  ['spaghetti', 'nan', 'ground beef', 'herb & pepper'],
#  ['mineral water', 'ground beef', 'spaghetti', 'milk'],
#  ['nan', 'ground beef', 'olive oil', 'milk'],
#  ['nan', 'ground beef', 'soup', 'milk'],
#  ['mineral water', 'ground beef', 'spaghetti', 'olive oil'],
#  ['mineral water', 'pancakes', 'ground beef', 'spaghetti'],
#  ['mineral water', 'ground beef', 'tomatoes', 'spaghetti'],
#  ['spaghetti', 'nan', 'ground beef', 'pepper'],
#  ['spaghetti', 'nan', 'shrimp', 'ground beef'],
#  ['spaghetti', 'nan', 'tomato sauce', 'ground beef'],
#  ['spaghetti', 'nan', 'mineral water', 'light cream'],
#  ['spaghetti', 'mineral water', 'olive oil', 'milk'],
#  ['spaghetti', 'mineral water', 'tomatoes', 'milk'],
#  ['nan', 'shrimp', 'olive oil', 'milk'],
#  ['nan', 'soup', 'olive oil', 'milk'],
#  ['spaghetti', 'nan', 'olive oil', 'milk'],
#  ['nan', 'tomatoes', 'soup', 'milk'],
#  ['spaghetti', 'nan', 'whole wheat pasta', 'milk'],
#  ['nan', 'soup', 'mineral water', 'olive oil'],
#  ['nan', 'whole wheat pasta', 'mineral water', 'olive oil'],
#  ['pancakes', 'nan', 'spaghetti', 'olive oil'],
#  ['spaghetti', 'nan', 'tomatoes', 'olive oil'],
#  ['spaghetti', 'nan', 'whole wheat rice', 'tomatoes'],
#  ['chocolate', 'eggs', 'nan', 'mineral water', 'ground beef'],
#  ['chocolate', 'nan', 'frozen vegetables', 'mineral water', 'ground beef'],
#  ['chocolate', 'spaghetti', 'nan', 'frozen vegetables', 'ground beef'],
#  ['chocolate', 'milk', 'nan', 'frozen vegetables', 'mineral water'],
#  ['chocolate', 'milk', 'spaghetti', 'nan', 'frozen vegetables'],
#  ['chocolate', 'shrimp', 'nan', 'frozen vegetables', 'mineral water'],
#  ['chocolate', 'spaghetti', 'nan', 'olive oil', 'mineral water'],
#  ['chocolate', 'shrimp', 'spaghetti', 'nan', 'mineral water'],
#  ['eggs', 'milk', 'nan', 'frozen vegetables', 'mineral water'],
#  ['frozen smoothie', 'milk', 'spaghetti', 'nan', 'mineral water'],
#  ['milk', 'nan', 'frozen vegetables', 'mineral water', 'ground beef'],
#  ['milk', 'spaghetti', 'nan', 'frozen vegetables', 'ground beef'],
#  ['spaghetti', 'nan', 'frozen vegetables', 'mineral water', 'ground beef'],
#  ['milk', 'nan', 'olive oil', 'frozen vegetables', 'mineral water'],
#  ['milk', 'nan', 'frozen vegetables', 'mineral water', 'soup'],
#  ['milk', 'spaghetti', 'nan', 'frozen vegetables', 'mineral water'],
#  ['shrimp', 'spaghetti', 'nan', 'frozen vegetables', 'mineral water'],
#  ['tomatoes', 'spaghetti', 'nan', 'frozen vegetables', 'mineral water'],
#  ['milk', 'spaghetti', 'nan', 'mineral water', 'ground beef'],
#  ['spaghetti', 'nan', 'olive oil', 'mineral water', 'ground beef'],
#  ['spaghetti', 'nan', 'pancakes', 'mineral water', 'ground beef'],
#  ['tomatoes', 'spaghetti', 'nan', 'mineral water', 'ground beef'],
#  ['milk', 'spaghetti', 'nan', 'olive oil', 'mineral water'],
#  ['tomatoes', 'milk', 'spaghetti', 'nan', 'mineral water']]
