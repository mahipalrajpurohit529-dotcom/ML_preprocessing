# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
x,y = make_regression(n_samples = 4 , n_features = 1 ,
       n_informative=1,
       n_targets=1,
       noise=80,random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
LinearRegression(copy_X= True,
                 fit_intercept= True,
                 n_jobs=True)
# Out:
# LinearRegression(n_jobs=True)

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# np.float64(26.15963284313262)

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x), color='red')

# %%
# Let's apply Gradient Descent assuming slope is
# constant = 78.35
# and Let's assume the starting value for
# intercept b = 0
y_pred = ((78.35*x)+0).reshape(4) #y = m*x+b

# %%
plt.scatter(x,y)
plt.plot(x , reg.predict(x) , color = 'red' ,
label = 'OLS')
plt.plot(x,y_pred , color = "green" , label = 'b = 0')
plt.legend()
plt.show()

# %%
m = 78.35
b = 0
loss_slope = -2*np.sum(y - m*x.ravel()-b)
loss_slope

####dL/db
# Out:
# np.float64(-209.27763408209216)

# %%
# Let's take Learning rate = 0.1

lr = 0.1
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-20.927763408209216)

# %%
# Calculating the new intercept
### b_new = b_old - Learning_rate * dL/db

b = b-step_size
b
# Out:
# np.float64(20.927763408209216)

# %%
y_pred1 =((78.35*x)+b).reshape(4)

plt.scatter(x,y)
plt.plot(x , reg.predict(x) , color = 'black' , label = 'OLS')
plt.plot(x , y_pred1 , color = 'red' , label = 'b = {} '.format(b))
plt.plot(x,y_pred , color = 'yellow' , label = 'b = 0')
plt. legend()
plt.show()

# %%
#Iteration - 2

loss_slope = -2*np.sum(y - m*x.ravel() - b)
loss_slope
# Out:
# np.float64(-41.85552681641843)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-4.185552681641844)

# %%
b = b - step_size
b
# Out:
# np.float64(25.11331608985106)

# %%
y_pred2 = ((78.35*x)+b).reshape(4)

plt.scatter(x,y)
plt.plot(x , reg.predict(x) , color = 'red' , label = 'OLS')
plt.plot(x , y_pred2 , color = 'green' , label = 'b = {}'.format(b))
plt.plot(x , y_pred1 , color = 'blue' , label = 'b = {}'.format(b))
plt.plot(x , y_pred , color = 'yellow' , label = 'b= 0')
plt.legend()
plt.show()

# %%
# Example

# ifi have b = 100 randomly

# Let's apply Gradient Descent assuming slope is constant = 78.35
# and Let's assume the starting value for intercept b = 100
y_pred = ((78.35*x)+100).reshape(4)

# %%
plt.scatter(x,y)
plt.plot(x , reg.predict(x) , color = 'red' ,
label = 'OLS')
plt.plot(x,y_pred , color = "green" , label = 'b = 100')
plt.legend()
plt.show()

# %%
m = 78.35
b = 100
loss_slope = -2*np.sum(y - m*x.ravel()-b)
loss_slope
# Out:
# np.float64(590.7223659179078)

# %%
lr = 0.1
step_size = loss_slope*lr
step_size
# Out:
# np.float64(59.072236591790784)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(59.072236591790784)

# %%
b = b - step_size*lr
b
# Out:
# np.float64(94.09277634082092)

# %%
y_pred1 =((78.35*x)+b).reshape(4)

plt.scatter(x,y)
plt.plot(x , reg.predict(x) , color = 'black' , label = 'OLS')
plt.plot(x , y_pred1 , color = 'red' , label = 'b = {} '.format(b))
plt.plot(x,y_pred , color = 'yellow' , label = 'b = 100')
plt. legend()
plt.show()

# %%
#  itteration 2 
loss_slope = -2*np.sum(y - m*x.ravel() - b)
loss_slope
# Out:
# np.float64(543.4645766444752)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(54.34645766444752)

# %%
b = b - step_size
b
# Out:
# np.float64(39.7463186763734)

# %%
y_pred1 =((78.35*x)+b).reshape(4)

plt.scatter(x,y)
plt.plot(x , reg.predict(x) , color = 'black' , label = 'OLS')
plt.plot(x , y_pred1 , color = 'red' , label = 'b = {} '.format(b))
plt.plot(x,y_pred , color = 'yellow' , label = 'b = 100')
plt. legend()
plt.show()

# %%
#  itteration 3
loss_slope = -2*np.sum(y - m*x.ravel() - b)
loss_slope
# Out:
# np.float64(108.69291532889504)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(10.869291532889505)

# %%
b = b - step_size
b
# Out:
# np.float64(28.877027143483893)

# %%
y_pred1 =((78.35*x)+b).reshape(4)

plt.scatter(x,y)
plt.plot(x , reg.predict(x) , color = 'black' , label = 'OLS')
plt.plot(x , y_pred1 , color = 'red' , label = 'b = {} '.format(b))
plt.plot(x,y_pred , color = 'yellow' , label = 'b = 100')
plt. legend()
plt.show()

# %%
# Example

# ifi have b = 200 randomly

# Let's apply Gradient Descent assuming slope is constant = 78.35
# and Let's assume the starting value for intercept b = 100
y_pred = ((78.35*x)+100).reshape(4)

# %%
plt.scatter(x,y)
plt.plot(x , reg.predict(x) , color = 'red' ,
label = 'OLS')
plt.plot(x,y_pred , color = "green" , label = 'b = 200')
plt.legend()
plt.show()

# %%
m = 78.35
b = 200
loss_slope = -2*np.sum(y - m*x.ravel()-b)
loss_slope
# Out:
# np.float64(1390.7223659179076)

# %%
lr = 0.1
step_size = loss_slope*lr
step_size
# Out:
# np.float64(139.07223659179076)

# %%
b = b - step_size
b
# Out:
# np.float64(60.927763408209245)

# %%
y_pred1 =((78.35*x)+b).reshape(4)

plt.scatter(x,y)
plt.plot(x , reg.predict(x) , color = 'black' , label = 'OLS')
plt.plot(x , y_pred1 , color = 'red' , label = 'b = {} '.format(b))
plt.plot(x,y_pred , color = 'yellow' , label = 'b = 200')
plt. legend()
plt.show()

# %%
#  itteration -- 2 
loss_slope = -2*np.sum(y - m*x.ravel()-b)
loss_slope
# Out:
# np.float64(278.1444731835818)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(27.81444731835818)

# %%
b = b - step_size
b
# Out:
# np.float64(33.11331608985107)

# %%
y_pred1 =((78.35*x)+b).reshape(4)

plt.scatter(x,y)
plt.plot(x , reg.predict(x) , color = 'black' , label = 'OLS')
plt.plot(x , y_pred1 , color = 'red' , label = 'b = {} '.format(b))
plt.plot(x,y_pred , color = 'yellow' , label = 'b = 200')
plt. legend()
plt.show()

# %%
# itteration -- 3
loss_slope = -2*np.sum(y - m*x.ravel()-b)
loss_slope
# Out:
# np.float64(55.62889463671638)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(5.562889463671638)

# %%
b = b - step_size
b
# Out:
# np.float64(27.55042662617943)

# %%
y_pred1 =((78.35*x)+b).reshape(4)

plt.scatter(x,y)
plt.plot(x , reg.predict(x) , color = 'black' , label = 'OLS')
plt.plot(x , y_pred1 , color = 'red' , label = 'b = {} '.format(b))
plt.plot(x,y_pred , color = 'yellow' , label = 'b = 200')
plt. legend()
plt.show()

# %%
# itteration -- 4
loss_slope = -2*np.sum(y - m*x.ravel()-b)
loss_slope
# Out:
# np.float64(11.125778927343276)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(1.1125778927343277)

# %%
b = b - step_size
b
# Out:
# np.float64(26.4378487334451)

# %%
y_pred1 =((78.35*x)+b).reshape(4)

plt.scatter(x,y)
plt.plot(x , reg.predict(x) , color = 'black' , label = 'OLS')
plt.plot(x , y_pred1 , color = 'red' , label = 'b = {} '.format(b))
plt.plot(x,y_pred , color = 'yellow' , label = 'b = 200')
plt. legend()
plt.show()
